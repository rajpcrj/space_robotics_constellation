# %%
'''
This jupyter file will load the npy torach tensors 
which is of size len(theta_inclinations) by len(raan_angles) by N_Rectannas by 2 

Define the reward function as J // or may be cost function I don't know Let's see
J maximize the average over 24 hours for all the rectannas. 
J= sigma(k,0,N_rectannas) sigma(t,0,86400) rectanna_k_power_recieved_at_t
constraint equation = g(rectannas for all k )> 0.85

'''
